# %%
# !pip install crewai==0.28.8 crewai_tools==0.1.6 langchain_community==0.0.29

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
from crewai import Agent, Task, Crew
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\utils\embedding_functions.py:395, in ONNXMiniLM_L6_V2.__init__(self, preferred_providers)
#     393 try:
#     394     # Equivalent to import onnxruntime
# --> 395     self.ort = importlib.import_module("onnxruntime")
#     396 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\onnxruntime\__init__.py:61
#      60 if import_capi_exception:
# ---> 61     raise import_capi_exception
#      63 from onnxruntime.capi.onnxruntime_inference_collection import (
#      64     AdapterFormat,  # noqa: F401
#      65     InferenceSession,  # noqa: F401
#    (...)
#      69     SparseTensor,  # noqa: F401
#      70 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\onnxruntime\__init__.py:24
#      23 try:
# ---> 24     from onnxruntime.capi._pybind_state import (
#      25         ExecutionMode,  # noqa: F401
#      26         ExecutionOrder,  # noqa: F401
#      27         GraphOptimizationLevel,  # noqa: F401
#      28         LoraAdapter,  # noqa: F401
#      29         ModelMetadata,  # noqa: F401
#      30         NodeArg,  # noqa: F401
#      31         OrtAllocatorType,  # noqa: F401
#      32         OrtArenaCfg,  # noqa: F401
#      33         OrtMemoryInfo,  # noqa: F401
#      34         OrtMemType,  # noqa: F401
#      35         OrtSparseFormat,  # noqa: F401
#      36         RunOptions,  # noqa: F401
#      37         SessionIOBinding,  # noqa: F401
#      38         SessionOptions,  # noqa: F401
#      39         create_and_register_allocator,  # noqa: F401
#      40         create_and_register_allocator_v2,  # noqa: F401
#      41         disable_telemetry_events,  # noqa: F401
#      42         enable_telemetry_events,  # noqa: F401
#      43         get_all_providers,  # noqa: F401
#      44         get_available_providers,  # noqa: F401
#      45         get_build_info,  # noqa: F401
#      46         get_device,  # noqa: F401
#      47         get_version_string,  # noqa: F401
#      48         has_collective_ops,  # noqa: F401
#      49         set_default_logger_severity,  # noqa: F401
#      50         set_default_logger_verbosity,  # noqa: F401
#      51         set_seed,  # noqa: F401
#      52     )
#      54     import_capi_exception = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\onnxruntime\capi\_pybind_state.py:32
#      25             warnings.warn("Please install the 2019 Visual C++ runtime and then try again. "
#      26                           "If you've installed the runtime in a non-standard location "
#      27                           "(other than %SystemRoot%\\System32), "
#      28                           "make sure it can be found by setting the correct path.")
# ---> 32 from .onnxruntime_pybind11_state import *  # noqa
#
# ImportError: DLL load failed while importing onnxruntime_pybind11_state: Falha numa rotina de inicialização de DLL (dynamic-link library).
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from crewai import Agent, Task, Crew
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\__init__.py:1
# ----> 1 from crewai.agent import Agent
#       2 from crewai.crew import Crew
#       3 from crewai.process import Process
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\agent.py:23
#      11 from pydantic import (
#      12     UUID4,
#      13     BaseModel,
#    (...)
#      19     model_validator,
#      20 )
#      21 from pydantic_core import PydanticCustomError
# ---> 23 from crewai.agents import CacheHandler, CrewAgentExecutor, CrewAgentParser, ToolsHandler
#      24 from crewai.memory.contextual.contextual_memory import ContextualMemory
#      25 from crewai.utilities import I18N, Logger, Prompts, RPMController
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\agents\__init__.py:2
#       1 from .cache.cache_handler import CacheHandler
# ----> 2 from .executor import CrewAgentExecutor
#       3 from .parser import CrewAgentParser
#       4 from .tools_handler import ToolsHandler
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\agents\executor.py:17
#      15 from crewai.agents.tools_handler import ToolsHandler
#      16 from crewai.memory.entity.entity_memory_item import EntityMemoryItem
# ---> 17 from crewai.memory.long_term.long_term_memory_item import LongTermMemoryItem
#      18 from crewai.memory.short_term.short_term_memory_item import ShortTermMemoryItem
#      19 from crewai.tools.tool_usage import ToolUsage, ToolUsageErrorException
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\memory\__init__.py:1
# ----> 1 from .entity.entity_memory import EntityMemory
#       2 from .long_term.long_term_memory import LongTermMemory
#       3 from .short_term.short_term_memory import ShortTermMemory
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\memory\entity\entity_memory.py:3
#       1 from crewai.memory.entity.entity_memory_item import EntityMemoryItem
#       2 from crewai.memory.memory import Memory
# ----> 3 from crewai.memory.storage.rag_storage import RAGStorage
#       6 class EntityMemory(Memory):
#       7     """
#       8     EntityMemory class for managing structured information about entities
#       9     and their relationships using SQLite storage.
#      10     Inherits from the Memory class.
#      11     """
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\memory\storage\rag_storage.py:7
#       4 import os
#       5 from typing import Any, Dict
# ----> 7 from embedchain import App
#       8 from embedchain.llm.base import BaseLlm
#       9 from embedchain.vectordb.chroma import InvalidDimensionException
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\embedchain\__init__.py:5
#       1 import importlib.metadata
#       3 __version__ = importlib.metadata.version(__package__ or __name__)
# ----> 5 from embedchain.app import App  # noqa: F401
#       6 from embedchain.client import Client  # noqa: F401
#       7 from embedchain.pipeline import Pipeline  # noqa: F401
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\embedchain\app.py:33
#      31 from embedchain.utils.misc import validate_config
#      32 from embedchain.vectordb.base import BaseVectorDB
# ---> 33 from embedchain.vectordb.chroma import ChromaDB
#      35 logger = logging.getLogger(__name__)
#      38 @register_deserializable
#      39 class App(EmbedChain):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\embedchain\vectordb\chroma.py:4
#       1 import logging
#       2 from typing import Any, Optional, Union
# ----> 4 from chromadb import Collection, QueryResult
#       5 from langchain.docstore.document import Document
#       6 from tqdm import tqdm
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\__init__.py:3
#       1 from typing import Dict, Optional
#       2 import logging
# ----> 3 from chromadb.api.client import Client as ClientCreator
#       4 from chromadb.api.client import AdminClient as AdminClientCreator
#       5 from chromadb.auth.token import TokenTransportHeader
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\__init__.py:7
#       5 from overrides import override
#       6 from chromadb.config import DEFAULT_DATABASE, DEFAULT_TENANT
# ----> 7 from chromadb.api.models.Collection import Collection
#       8 from chromadb.api.types import (
#       9     CollectionMetadata,
#      10     Documents,
#    (...)
#      23     WhereDocument,
#      24 )
#      25 from chromadb.config import Component, Settings
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\models\Collection.py:57
#      53 if TYPE_CHECKING:
#      54     from chromadb.api import ServerAPI
# ---> 57 class Collection(BaseModel):
#      58     name: str
#      59     id: UUID
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\models\Collection.py:74, in Collection()
#      64 _embedding_function: Optional[EmbeddingFunction[Embeddable]] = PrivateAttr()
#      65 _data_loader: Optional[DataLoader[Loadable]] = PrivateAttr()
#      67 def __init__(
#      68     self,
#      69     client: "ServerAPI",
#      70     name: str,
#      71     id: UUID,
#      72     embedding_function: Optional[
#      73         EmbeddingFunction[Embeddable]
# ---> 74     ] = ef.DefaultEmbeddingFunction(),  # type: ignore
#      75     data_loader: Optional[DataLoader[Loadable]] = None,
#      76     tenant: Optional[str] = None,
#      77     database: Optional[str] = None,
#      78     metadata: Optional[CollectionMetadata] = None,
#      79 ):
#      80     super().__init__(
#      81         name=name, metadata=metadata, id=id, tenant=tenant, database=database
#      82     )
#      83     self._client = client
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\utils\embedding_functions.py:566, in DefaultEmbeddingFunction()
#     564     return None
#     565 else:
# --> 566     return ONNXMiniLM_L6_V2()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\utils\embedding_functions.py:397, in ONNXMiniLM_L6_V2.__init__(self, preferred_providers)
#     395     self.ort = importlib.import_module("onnxruntime")
#     396 except ImportError:
# --> 397     raise ValueError(
#     398         "The onnxruntime python package is not installed. Please install it with `pip install onnxruntime`"
#     399     )
#     400 try:
#     401     # Equivalent to from tokenizers import Tokenizer
#     402     self.Tokenizer = importlib.import_module("tokenizers").Tokenizer
#
# ValueError: The onnxruntime python package is not installed. Please install it with `pip install onnxruntime`
